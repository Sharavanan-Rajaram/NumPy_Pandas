# %% [markdown]
# ## Kaggle games Dataset

# %% [markdown]
# We will be using the [games Dataset](https://www.kaggle.com/gutsyrobot/games-data/data) from Kaggle.

# %%
import pandas as pd
import os

# %% [markdown]
# **Q.no(1). load the Data 'games.csv' as games.**

# %%
data_excel=pd.read_csv('games.csv')

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(2). Check the head of the DataFrame.**

# %%
data_excel.head()
# Out:
#        id       type                                       name  \
# 0   12333  boardgame                          Twilight Struggle
# 1  120677  boardgame                              Terra Mystica
# 2  102794  boardgame                  Caverna: The Cave Farmers
# 3   25613  boardgame  Through the Ages: A Story of Civilization
# 4    3076  boardgame                                Puerto Rico
#
#    yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0         2005.0         2.0         2.0        180.0        180.0
# 1         2012.0         2.0         5.0        150.0         60.0
# 2         2013.0         1.0         7.0        210.0         30.0
# 3         2006.0         2.0         4.0        240.0        240.0
# 4         2002.0         2.0         5.0        150.0         90.0
#
#    maxplaytime  minage  users_rated  average_rating  bayes_average_rating  \
# 0        180.0    13.0        20113         8.33774               8.22186
# ...

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(3)How many rows and columns are there.**

# %%
data_excel.shape
# Out:
# (81312, 20)

# %%
data_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81312 entries, 0 to 81311
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    81312 non-null  int64
#  1   type                  81312 non-null  object
#  2   name                  81271 non-null  object
#  3   yearpublished         81309 non-null  float64
#  4   minplayers            81309 non-null  float64
#  5   maxplayers            81309 non-null  float64
#  6   playingtime           81309 non-null  float64
#  7   minplaytime           81309 non-null  float64
#  8   maxplaytime           81309 non-null  float64
#  9   minage                81309 non-null  float64
#  10  users_rated           81312 non-null  int64
#  11  average_rating        81312 non-null  float64
#  12  bayes_average_rating  81312 non-null  float64
#  13  total_owners          81312 non-null  int64
# ...

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(4). What is the average Playingtime of all the players in the dataset.**

# %%
data_excel['playingtime'].mean()
# Out:
# 51.63478827682052

# %% [markdown]
# -------------------

# %% [markdown]
# **Q.no(5).What is the highest number of comments received for a game.**

# %%
data_excel['total_comments'].max()
# Out:
# 11798

# %% [markdown]
# -------

# %% [markdown]
# **Q.no(6).What is the name of the game with id 1500.**

# %%
data_excel[data_excel['id']==1500]['name']
# Out:
# 10592    Zocken
# Name: name, dtype: object

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(7).which year the game with id 1600 was published.**

# %%
data_excel[data_excel['id']==1600]['yearpublished']
# Out:
# 13270    1986.0
# Name: yearpublished, dtype: float64

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(8).Which game has received highest number of comments.**

# %%
data_excel[data_excel['total_comments']== data_excel['total_comments'].max()]['name']
# Out:
# 165     Catan
# 1965    Catan
# Name: name, dtype: object

# %%
data_excel[data_excel['total_comments']== data_excel['total_comments'].max()]
#to see the games
# Out:
#       id       type   name  yearpublished  minplayers  maxplayers  \
# 165   13  boardgame  Catan         1995.0         3.0         4.0
# 1965  13  boardgame  Catan         1995.0         3.0         4.0
#
#       playingtime  minplaytime  maxplaytime  minage  users_rated  \
# 165          90.0         90.0         90.0    10.0        53680
# 1965         90.0         90.0         90.0    10.0        53680
#
#       average_rating  bayes_average_rating  total_owners  total_traders  \
# 165          7.34303               7.21171         73188           1071
# 1965         7.34303               7.21171         73188           1071
#
#       total_wanters  total_wishers  total_comments  total_weights  \
# 165             391           3201           11798           5996
# 1965            391           3201           11798           5996
#
#       average_weight
# 165           2.3712
# 1965          2.3712

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(9).Which games have received least number of comments**

# %%
data_excel[data_excel['total_comments']==data_excel['total_comments'].min()]['name']
# Out:
# 13048                                           Looney Leo
# 13054                                                 Dump
# 13068                                        Field of Fire
# 13095                                             Matheeno
# 13103    Auction America: The Trivia Game for Any Colle...
#                                ...
# 81307                                 Micro Rome: Aegyptus
# 81308    Trivial Pursuit: Marvel Cinematic Universe  Da...
# 81309                                            BEARanoia
# 81310                                              Freight
# 81311                                    Bingo Animal Kids
# Name: name, Length: 29001, dtype: object

# %%
data_excel[data_excel['total_comments']==data_excel['total_comments'].min()]
# Out:
#            id                type  \
# 13048     318           boardgame
# 13054     468           boardgame
# 13068     579           boardgame
# 13095     738           boardgame
# 13103     778           boardgame
# ...       ...                 ...
# 81307  184441  boardgameexpansion
# 81308  184442           boardgame
# 81309  184443           boardgame
# 81310  184449           boardgame
# 81311  184451           boardgame
#
#                                                     name  yearpublished  \
# 13048                                         Looney Leo            0.0
# 13054                                               Dump            0.0
# 13068                                      Field of Fire         2002.0
# 13095                                           Matheeno         2000.0
# 13103  Auction America: The Trivia Game for Any Colle...         2000.0
# ...                                                  ...            ...
# ...

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(10).How many unique games are there in the dataset.**

# %%
data_excel['name'].nunique()

#to get the count of total unique games
# Out:
# 76035

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(11).How many game types are present in the dataset.**

# %%
data_excel['type'].nunique()
# Out:
# 2

# %%
#data_excel['type'].unique() for seeing those games

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(12) Show the average ratings of games in ascending order.**

# %%
data_excel.sort_values(by='average_rating') #Shows full table
#Default is ascending
#data_excel.sort_values(by='average_rating')['average_rating'] - shows only this average ratings
# Out:
# 81311     0.0
# 46614     0.0
# 46615     0.0
# 46616     0.0
# 46617     0.0
#          ...
# 76117    10.0
# 76116    10.0
# 55328    10.0
# 80276    10.0
# 64898    10.0
# Name: average_rating, Length: 81312, dtype: float64

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(13) Show the average ratings of games in descending order.**

# %%
data_excel.sort_values(by='average_rating',ascending=False)
# Out:
#            id                type  \
# 74808  166729  boardgameexpansion
# 62260  127567  boardgameexpansion
# 72670  160007           boardgame
# 78071  175640           boardgame
# 79305  179159  boardgameexpansion
# ...       ...                 ...
# 50664   70942           boardgame
# 50661   70938           boardgame
# 50659   70925           boardgame
# 50653   70915           boardgame
# 81311  184451           boardgame
#
#                                                     name  yearpublished  \
# 74808  Age of Conan: The Strategy Board Game  Adventu...         2015.0
# 62260                                       -(Mathul8)^2         2011.0
# 72670                                             Kamara         2014.0
# 78071                              Vinhos Deluxe Edition         2016.0
# 79305            Zombicide: Black Plague Survivor  Gowan         2015.0
# ...                                                  ...            ...
# ...

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(14).What is the dense rank order of the games as per there average rating.**

# %%
data_excel['average_rating_dense']=data_excel['average_rating'].rank(method='dense')
data_excel[['name','average_rating_dense']]
#Default ascending is 0
# Out:
#                                                     name  average_rating_dense
# 0                                      Twilight Struggle               17105.0
# 1                                          Terra Mystica               17041.0
# 2                              Caverna: The Cave Farmers               17044.0
# 3              Through the Ages: A Story of Civilization               16909.0
# 4                                            Puerto Rico               16788.0
# ...                                                  ...                   ...
# 81307                               Micro Rome: Aegyptus                   1.0
# 81308  Trivial Pursuit: Marvel Cinematic Universe  Da...                   1.0
# 81309                                          BEARanoia                   1.0
# 81310                                            Freight                   1.0
# 81311                                  Bingo Animal Kids                   1.0
#
# ...

# %% [markdown]
# ------

# %% [markdown]
# # --------------------------------HAPPY LEARNING---------------------------------------

# %% [markdown]
# -------
